# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

rng = np.random.default_rng(seed=100)

# %%
#Q1
K=10
grid = np.linspace(1/K, 1.0, K)
rng.choice(grid, size=1)
# Out:
# array([0.8])

# %%
draws = rng.choice(grid, size=5_000)
sns.ecdfplot(data=draws)
# Out:
# <Axes: ylabel='Proportion'>

# %% [markdown]
# ## Q1.4
#
# As we increase K, this distribution approaches the uniform distribution. The ecdf here is showing equal probabilities amongst all values.

# %%
#Q2.1 and 2.2
sample = rng.uniform(-np.sqrt(3), np.sqrt(3), size=32)
np.mean(sample) * np.sqrt(n)
# Out:
# np.float64(11.127772275919487)

# %%
#Q2.3
process = rng.uniform(-np.sqrt(3), np.sqrt(3), size=(5000, 32))
repeat = np.mean(process, axis=1) * np.sqrt(n)
sns.ecdfplot(data=repeat)
# Out:
# <Axes: ylabel='Proportion'>

# %% [markdown]
# ## 2.4
#
# As n increases, this simulation approaches the normal distribution. The ECDF shows the density plot of a normal distribution and the mean + var being 0 and 1 are also prime indicators.
