# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/witze/Downloads/uu_categorical_and_numeric/data/metabric.csv')
df.head(10)
# Out:
#    Age at Diagnosis Type of Breast Surgery    Cancer Type Chemotherapy  \
# 0             43.19      BREAST CONSERVING  Breast Cancer           NO
# 1             48.87             MASTECTOMY  Breast Cancer          YES
# 2             47.68             MASTECTOMY  Breast Cancer          YES
# 3             76.97             MASTECTOMY  Breast Cancer          YES
# 4             78.77             MASTECTOMY  Breast Cancer           NO
# 5             56.45      BREAST CONSERVING  Breast Cancer          YES
# 6             89.08      BREAST CONSERVING  Breast Cancer           NO
# 7             86.41      BREAST CONSERVING  Breast Cancer           NO
# 8             84.22             MASTECTOMY  Breast Cancer           NO
# 9             85.49             MASTECTOMY  Breast Cancer           NO
#
#   Hormone Therapy  Lymph nodes examined positive  Mutation Count  \
# 0             YES                            0.0             2.0
# ...

# %%
sns.ecdfplot(data=df, x='Overall Survival (Months)')
# Out:
# <Axes: xlabel='Overall Survival (Months)', ylabel='Proportion'>

# %%
sns.ecdfplot(data=df, x='Overall Survival (Months)', hue='Chemotherapy')
# Out:
# <Axes: xlabel='Overall Survival (Months)', ylabel='Proportion'>

# %% [markdown]
# - (6b) Conditional on a patient receiving Chemotherapy, we predict that patient will live a shorter amount of time. This is because a patient requiring Chemotherapy are in a much worse health condition than a patient that doesn't require Chemotherapy. To make a relevant analogy, a group of people who pulled an all nighter studying for an exam will always get worse grades than a group of people who got good sleep.
#
# - (6c) I believe chemotherapy is still an effective treatment. There is an impact from indication bias that creates the illusion that chemotherapy directly causes a decrease in survival. Due to the presence of this bias, we can't make any conclusions on the safety and effectiveness of Chemotherapy.
